# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Rounak\\Desktop\\OneDrive\\College\\Projects\\Severity-of-Toxic-Commentis-End-to-End'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path
    tokenizer_path: Path
    # potential_stopwords: list
    # re_patterns: dict

# %%
from SeverityOfToxicCommentsEndToEnd.utils.common import read_yaml, create_directories
from SeverityOfToxicCommentsEndToEnd.constants import *
from DataTransformationParam import *

# %%
class ConfigurationManager:
    def __init__(self, config_filepath = CONFIG_FILE_PATH, params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir = config.root_dir,
            data_path = config.data_path,
            tokenizer_path = config.tokenizer_path,
            # potential_stopwords = config.potential_stopwords,
            # re_patterns = config.RE_PATTERNS
        )
        return data_transformation_config

# %%
import os
from SeverityOfToxicCommentsEndToEnd.logging import logger
import re
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
import itertools
from string import ascii_lowercase
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Rounak\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(potential_stopwords)
# Out:
# ['editor', 'reference', 'thank', 'work', 'find', 'good', 'know', 'like', 'look', 'thing', 'want', 'time', 'list', 'section', 'wikipedia', 'doe', 'add', 'new', 'try', 'think', 'write', 'use', 'user', 'way', 'page']

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config
        self.stopword_list = []
        self.dual_alpha_list = []
        self.train_text = []
        self.lemma_train_text = []
        self.processed_train_text = []
    
    def clean_text(self, text, remove_repeat_text=True, remove_patterns_text=True, is_lower=True):

        if is_lower:
            text=text.lower()
            
        if remove_patterns_text:
            for target, patterns in RE_PATTERNS.items():
                for pat in patterns:
                    text=str(text).replace(pat, target)

        if remove_repeat_text:
            text = re.sub(r'(.)\1{2,}', r'\1', text) 

        text = str(text).replace("\n", " ")
        text = re.sub(r'[^\w\s]',' ',text)
        text = re.sub('[0-9]',"",text)
        text = re.sub(" +", " ", text)
        text = re.sub("([^\x00-\x7F])+"," ",text)
        return text 
    
    def lemma(self, text, lemmatization=True):
        lemmatizer = WordNetLemmatizer()
        output=''
        if lemmatization:
            text=text.split(' ')
            for word in text:
                word1 = lemmatizer.lemmatize(word, pos = "n") #noun 
                word2 = lemmatizer.lemmatize(word1, pos = "v") #verb
                word3 = lemmatizer.lemmatize(word2, pos = "a") #adjective
                word4 = lemmatizer.lemmatize(word3, pos = "r") #adverb
                output=output + " " + word4
        else:
            output=text
        
        return str(output.strip())
    
    def iter_all_strings(self):
        for size in itertools.count(1):
            for s in itertools.product(ascii_lowercase, repeat=size):
                yield "".join(s)
    
    def dual_alpha(self):
        for s in self.iter_all_strings():
            self.dual_alpha_list.append(s)
            if s == 'zz':
                break
    
    def alter_dual_alpha(self):
        self.dual_alpha_list.remove('i')
        self.dual_alpha_list.remove('a')
        self.dual_alpha_list.remove('am')
        self.dual_alpha_list.remove('an')
        self.dual_alpha_list.remove('as')
        self.dual_alpha_list.remove('at')
        self.dual_alpha_list.remove('be')
        self.dual_alpha_list.remove('by')
        self.dual_alpha_list.remove('do')
        self.dual_alpha_list.remove('go')
        self.dual_alpha_list.remove('he')
        self.dual_alpha_list.remove('hi')
        self.dual_alpha_list.remove('if')
        self.dual_alpha_list.remove('is')
        self.dual_alpha_list.remove('in')
        self.dual_alpha_list.remove('me')
        self.dual_alpha_list.remove('my')
        self.dual_alpha_list.remove('no')
        self.dual_alpha_list.remove('of')
        self.dual_alpha_list.remove('on')
        self.dual_alpha_list.remove('or')
        self.dual_alpha_list.remove('ok')
        self.dual_alpha_list.remove('so')
        self.dual_alpha_list.remove('to')
        self.dual_alpha_list.remove('up')
        self.dual_alpha_list.remove('us')
        self.dual_alpha_list.remove('we')

        for letter in self.dual_alpha_list:
            self.stopword_list.append(letter)
    
    def alter_stopwords(self):
        for word in potential_stopwords:
            self.stopword_list.append(word)
        print(len(self.stopword_list))

    def remove_stopwords(self, text, remove_stop=True):
        output = ""
        if remove_stop:
            text=text.split(" ")
            for word in text:
                if word not in self.stopword_list:
                    output=output + " " + word
        else :
            output=text

        return str(output.strip())
    
    def perform_data_transformation(self):
        df = pd.read_csv(self.config.data_path)
        for line in df['comment_text']: 
            self.train_text.append(self.clean_text(line))

        for line in self.train_text:
            self.lemma_train_text.append(self.lemma(line))
        
        self.dual_alpha()
        self.alter_dual_alpha()
        self.alter_stopwords()
        for line in self.lemma_train_text: 
            self.processed_train_text.append(self.remove_stopwords(line))
    
    def tokenizer(self):
        tokenizer = Tokenizer(num_words=max_features)
        tokenizer.fit_on_texts(list(self.processed_train_text))
        list_tokenized_train = tokenizer.texts_to_sequences(self.processed_train_data)
        word_index=tokenizer.word_index
        training_padded=pad_sequences(list_tokenized_train, maxlen=maxpadlen, padding = 'post')

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config = data_transformation_config)
    result = data_transformation.perform_data_transformation()

except Exception as e:
    raise e
# Out:
# [2023-07-11 20:22:22,247: INFO: common] Successfully read yaml file from config\config.yaml
# [2023-07-11 20:22:22,249: INFO: common] Successfully read yaml file from params.yaml
# [2023-07-11 20:22:22,253: INFO: common] Created directory at: artifacts
# [2023-07-11 20:22:22,256: INFO: common] Created directory at: artifacts/data_transformation
# 700

# %%
result
# Out:
# ['geez be you forgetful we already discuss why marx not an anarchist i he to a state to mold his socialist man ergo he be a statist the opposite of an anarchist i a guy who say that when he get old and his teeth fall out he quit eat meat would you call him a vegetarian',
#  'carioca rfa for your support on my request for adminship the final outcome so i be now an administrator if you have any comment or concern on my action a an administrator please let me you',
#  'birthday no worry what i do enjoy day talk',
#  'pseudoscience category i assume that this article be in the pseudoscience category because of association with creationism however there be modern scientifically accept variant of catastrophism that have nothing to do with creationism and they even mention in the article i the connection to pseudoscience need to be clarify or the article make more general and creationism specific and the category tag remove entirely',
#  'and if such phrase exist would be provide by search engine even if mention be not available a a whole',
#  'october utc the delta function i in the example above a be the kronecker delta not the dirac delta the kronecker delta be in whereas the dirac delta be not in incidentally in response to the request for example be not a rkhs for any open bullshit of on the other hand hardy space usually be rkhss various variant of the szego kernel for example the hilbert space of function on the circle be not a rkhs on the other hand the space of function on the circle which be tangential limit of holomorphic function on the disc be',
#  'september couvet',
#  'negro league baseball task force talk',
#  'of my three son episode i saw you redirect two of the season episode back to the article a month ago which remove them from both article since transcluded i bullshit tituted the back into the main article and about to remove the link back to the season but the other season still have separate i i just ask for your might be easy to just undo the bullshit titution and redirect',
#  'quote loremaster in order to make sure you understand me',
#  'please do not vandalize a you do with this edit to holmes chapel comprehensive school if you continue to do so you will be block from edit',
#  'by be probably the most common variation on both and common be also in a compatible with the gfdl by default any limitation might disqualify a free enough for most notably free image here must allow for commercial reuse again for gfdl compatibility i presume so be out of the question though i not an expert on this you can check the upload wizard follow the own path and see the available choice though you might also seriously consider upload the image to common instead to allow wide',
#  'actually that go now you the only one name him now',
#  'move the article to full english title keep in line with article title english language title full title of the instead of just popular abbreviation any search of bookstore show that the be most widely publish and available today under full english title a oppose to any of the latin variant which be popular during the renaissance the current title reflect what the would most likely be recognize search for i also create direct for on the mystery of the egyptian to here',
#  'there be so many article that wish to down play the part of the religion that they really don understand i will not go back in and change the article if people to discredit something they don understand that be ok this be say be in no direct to anyone in particular i just interest that people to up document report on religion that they be no part of there be on cathlics baptist and other religion that state opinion of people who be not even a part of those religion to me and this be personal be very sad when there be people who will critically analzye something that they do not believe in themselves well',
#  'i see you have such a low self esteem that you have to warn others not to attack you',
#  'poor i shouldn have to check his edit history he should reply to me at my talk i that wasn the right but what be the right that my point i don to admin him i to complain about his action',
#  'that be not a of official name of official neighborhood their be no such that exist that be a of neighborhood name of which more then half be no long that be take from philadelphia almanac and citizen manual which edit by kenneth finkel and publish by the library company of philadelphia in and be augment by the staff of the philadelphia city archive the edition of this book contain different name of various neighborhood throughout the city of philadelphia from the early day of swedish occupation to the present the follow year an additional six name be to bring the to this be be augment yet again by the philadelphia city archive with name of neighborhood redevelopment area and other place name which have be assign officially or unofficially to certain area of the city be interest to see the dynamic of neighborhood name in over year of occupation of the square mile which comprise philadelphia by the native american the swede the english and german pioneer and late and current philadelphians cht',
#  'yes merge chamin and cholent be one and the same cholent be the yiddish term which be the mostly widely whereas chamin be hebrew and mainly in israel primarily by sephardi mizrahi family',
#  'july utc there be a number of key word or red flag on they have a very strong effect in the community disruptive edit be one of them if you to abuse your position a a trust here you say the you have a difference of opinion with be disruptive when he or she simply a different opinion a you so correctly mention confidently demonstrate with reliable source that a statement be an encyclopedic statement appropriate to be on be not disruptive edit however the term disruptive edit be one of a number of term abuse by abusive on be very dishearten when some trust immediately that term against you when you simply have a different opinion they the power of that word that be why they there be a number of these power word in the community abusively this tactic be a personal attack in my opinion the other involve here also state my contribution in various article be waste wikipedians he also consider the fact that i address you and other by name a something that can be in a negative against me',
#  'i just go to state a i have bullshit erved that the do not state that there be a surname a house and family not mean a house and a surname there be a house of oldenburg which be also the oldenburg family for instance royal birth certificate do not a surname charles prince of wale do not a surname on his marriage certificate how be clear that the royal family do and have a surname',
#  'no worry we will another account and will not stop until stop push the evil sin fill gay agenda',
#  'do not repeatedly nonsense to article',
#  'question hello latics i notice that you revert vandalism occasionally would you me to grant your account rollback right to make vandal fight easy for you just remember that rollback twinkle should only be to revert vandalism and that misuse of the tool can lead to removal tell me what you',
#  'murphy art center copyvio could you confirm the url of the copyvio source http homepage mac com i hpti wimg share slideshow slideshow html lang be the correct url a doesn properly for me i remove the suspect copyvio content in the interim land',
#  'by the who do you you be warn me about remove totally unrelated music track from a disco trust me you not the only person on this planet who be or still be involve in disco since the seventy get offa that clowd why don you i have do more radio than you ever will so don talk to me i be anti radio or something jun utc',
#  'renzoy shut the fuck up',
#  'hey everybody do ahh relief',
#  'email i just the email this function how can i get ahold of a copy of the email i just send karwynn',
#  'no i never say one be than the other they be equally bias i have never talltale anywhere in fact balakian copy verbatim his information from dardian who say he get from vakit newspaper whcih i explain many already which nobody alive or dead corroborate nobody can verify the vakit article this be make up point of and bias i be not tell you again why you can not armenian source you need to read this and point everything if you have a problem with those then respond otherwise i be warn for the last stop vandalise this you be also do soapbox advertise the armenian political agenda',
#  'wpww hi i don if you see the conversation at talk wikiproject woman writer authority control a huge project and really need to include all writer bios not just woman writer but stick with wpww scope would be limit to woman probably bot not awb right',
#  'i hope you be have a great holiday and at your convenience could you please get back to me i to first congratulate you on over contribution i first hand the feel you get when achieve great you and your fellow administrator have make and continue to make a brilliant place to go for correct information i to apologize if the http org wiki brian_j _esposito brian esposito violate any of these internal rule i under the impression that my accomplishment which be source by company such a inc magazine hearst publication bir report beauty store business asbury park press kikscore the national retail federation nrf and many more be valid enough i would to with you in correct any issue and to have this restore i be continue to make great stride for my company employee and my family have this also act a a of help me continue to accomplish my goal and dream i forward in hear back from you and also learn from you on how to correctly do the right when come to you for your brian esposito ceo aveyou beauty boutique ceo president founder paybaq precede unsigned comment by talk contri bullshit wasn really so much my decisioon to delete this a my enforce a consensus of at article for deletion brian esposito i suggest that thorough read of if you be interest in get back but frankly we be non profit project not a vehicle for self publication and promotion and i would advise you to stay away from the to avoid a conflict of interest humbug you very much for take the to get back to me regard this issue by no mean the create to self promote or profit and continue to be update with all the great we be get do at salon professional service inc and paybaq all the article mention and partnership display that success especially the we do together with microsoft in help small business around the globe i apologize if the come across in any a violation to the policy i have review the and be not sure what else can be do to correct this and hopefully have delete there be real credit milestone and achievement myself and my team have reach we also have a few more credit include a book release by the small business association which we have a big part in and the internet retailer edition you for your continue help and i hope you be have a great day and have a beautiful vacation brian precede unsigned comment by just be friendly swistertwister give you a cookie cooky promote wikilove and hopefully this one make your day you can spread the wikilove by give someone else a cookie whether be someone you have have disagreement with in the past or a friend to spread the goodness of cooky you can to someone talk with a friendly message or eat this cookie on the giver talk with i how hard on can build up an appetite so i hope this cookie will make your day talk you very much for take the to get back to me regard this issue by no mean the create to self promote or profit and continue to be update with all the great we be get do at salon professional service inc and paybaq all the article mention and partnership display that success especia',
#  'third party bullshit ervations leave at user_talk elonka _npa_claim_against_josiah_rowe talk',
#  'in this instance i don believe there be much potential for conflict of interest first none of the surgeon themselves appear in involve in the creation or maintenance of this second the provide basic general information third most of the well practitioner be and provide in alphabetical order fourth the surgeon be hardly in need of extra business since of all them have quite long wait fifth their potential patient be generally internet connect and quite likely to utilize search to locate informaton about them sixth give the nature of this particular type of surgery and the generous people who perform often at risk of criticism from some bias group should not be hide from view or make to appear marginalize in any',
#  'top no at all the great base stealer and hall of famers that would be delete from this the should stay the same with the top because steal in a career be still a notable stat',
#  'quackguru luck with your communication attempt and for the help if you another challenge you might to read the discussion that i have be have with ronz about the same topic area a quackguru be refer to and see if you can help communicate with him a well i win give you the detail of the situation so you can come in fresh but there plenty to read on my talkpage and archive and also on ronz talkpage though you also have to go into the history of his since he often delete my message or you may just wish to post a note on his talkpage and say ronz i hear you ask for a mediator in communicate with elonka may i help onka',
#  'suck my dik suck my dik gogo gogo give blowjo bullshit on demand',
#  'still you dihoest self yur integrity hasn improve',
#  'please do not me more silly perhaps no one tell you but you obviously frustrate and i would that please do not me more for my part i have decide that i will not bring anything more to because be a monopoly of information manipulate by a lot of abnormals you',
#  'you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk you a jerk jackass',
#  'hi kannadiga shame on you you a terrible as now with that false citation kannadiga where do you say urdu originate africa despite all the lie and idiocy you spew you and a handful of kanndadigas you be a valuable encyclopedic contributor',
#  'your of multiple account',
#  'to paul or whomever take the responsibility for editting this while i admire your dedication to uphold a neutral point of view in this article i must voice the opinion that you lack acknowledgment towards the fact that he be a controversial figure to indian be not in line in general with there be many example of article on this we bullshit ite that provide info about controversial issue in a neutral position while usually provide material for and against the issue i that that would be the only to present a truly fair and neutral portrayal of max muller one other consideration for yourself would be what be you consider a mainstream opinion because i be sure that you be aware of the politics that go into get a paper publish and the bias that can play for or against finally your vehement refutation of other source base on who be he show your own inability to question and research into idea contradictory to others i would recommend that if you be go to portay a neutral article please do so by give both side of the story incidentally i not a nationalist and i not a member of hindutwa i be however a person that to search for and be present with all relevant information whether they be contradictory to my own opinion or not raj',
#  'that be a useful correction but the number of set that have to be search in the bomy and bomb still',
#  'seem a reasonable request reasonable to me',
#  'you just make my point that my addition volunteer move',
#  'definition of web on internet i take issue with the definition of the on the internet a collection of document wouldn be more accurate to say that the web be a graphical interface we to access file on the internet because don lot of people now say they go to upload a video to the web or download a podcast from the web they don say they go to go at an html with some ajaxy stuff that allow them to view a video',
#  'once again leave me alone you be bother me for the sake of bother me you don even need to reply just stop type and press save on my talk please you',
#  'nevada meme on check all reliable source i could in the article i could nothing about this whole nevada much a to a nickname which in any case appear to have be give to the killer after the crime since merely seem to be an internet meme and even the article claim that there no whether the nevada picture relate to the kill i remove the if the girl in the nevada picture be not from reliable source to be the killer obviously grossly irresponsible for to represent the picture and the unreliable we bullshit ites that refer to them a those of the murderer if we can come up with a reliable source that actually refer to the nevada meme then we can document a such anticipation of a lover arrival the',
#  'you lengthned my block again to two week for what now for live admins protect me from agresor kafziel',
#  'december please stop remove speedy deletion notice from that you have create yourself if you continue you will be block from edit do not replace the speedy deletion template with the hangon template put the hangon template below',
#  'newser be a blog about journalism by professional journalist so i that be exactly the kind of source we need here',
#  'no difference simply two branch of the same nation',
#  'your tool edit count summary i wonder if your count summary on tangotango rfa self make or generate by a bot if the latter i may to one',
#  'true but then our remark on this bullshit cure webpage haven be either so your or be of no consequence either a reliable souce that state that elvis jewish and explain why or drop the argument',
#  'tekken on they say tekken will be on also http gtv com thefeed blog post tekken__on_the_ps__fall_ html',
#  'the title issue be a little more serious than you be give credit for there be a format for title at and they should make sense in english which this one doesn be ungrammatical and don that there aren a number of who will that there be indeed a separate catholic virgin mary that be an accusation of some protestant evangelical group at the moment so would make sense to listen a little to what other people be say the present title be ungrammatical and mislead and should be change a per my suggestion or in some other',
#  'you get ok you have the right idea now liam let me if you have any question',
#  'by the i remember the first israeli claim shortly after the attack against the ship and the kill accord to which the activist have firearm with them on bord and also that on the freight for gaza be such',
#  'unauthorised change on january i just in the last few week mzilikazi change this article from the standard form of date in the english language to bce a he well this violate specifically era which require that any change to an article date style first be discuss on the talk and justify with article specific reason before consensus be establish and the article be then ready to be change a be clearly evident to everyone none of these step have take place in this case instead in the two and fro of the last few week a aesop go back and forth between the queen english and bce mzilikazi and his friend have claim that the comment much far up this talk and date month ago constitute the necessary discussion and consensus for the change of apart from the obvious fact that the article remain in the standard english state for month continuously may to january those comment be never enough to justify the change to bce even back then this be of course because a mention early era require that article specific reason be give and consensus establish neither occur then what we see from can at best be call a disgrace merely dougweller and his friend make the laughably fallacious and tendentious claim that because there be more of them they should automatically get their without have to justify their case or convince anyone of the discussion go quiet in unresolved state and the change from the queen english which the article since creation and the overwhelm majority of the since then to bce therefore didn proceed at least until month late when mzilikazi decide to again this without any attempt to follow the proper procedure if mzilikazi and his friend to legitimately change aesop from the establish english language abbreviation to bce then by all mean discus here and follow the proper process stop to ram through your illegal change with constant back and forth edit',
#  'ambarish srivastava ambarish srivastava even sir above article ambarish srivastava nominate for deletion review on february the result of the discussion move to main space you have participate in that discussion thoroughly check and edit by you also i be grateful to you for your kind support at that at present spacemanspiff who nominate this article for afd previously delete major part under poetry which cite properly a well a he also delete whole architectural on yesterday december and december i contact spacemanspiff on his talk where he answer to me you can not photograph of build a for by the person we need reliable source likewise submit content site be not valid for poetic contribution and link to every poem on such site run afoul of our external link policy suggest you read blp and npov if that content not a per blp and npov then why he could not delete previously when this move to main space while fayenatic london make some quarry about on august august august august august august he satisfy with my answer about those i request you to check be justify if not please help a lot',
#  'actually the real world source and policy be with and there no consensus',
#  'the permission on those be a they be since you seem to understand the permission process than i feel free to take whatever action you feel be necessary to get the official duck in a row',
#  'sockpuppet no stifle just what do you your do i too hard for you to do this and why dont assume at my contribution and what have i do what tie me to smugface a you and every second person belives and what set apart constructive edit thats bloody what remove or an answer not happy jan could we not discus this in the stead of dirty up each others your contribution pattern be very similar very little article contribution cause general annoyance and yell at anyone who to call you on',
#  'pro life alliance the article pro life alliance be nominate for deletion',
#  'you a dumb american right no degree nothing of engineer mathematics be universal play monopoly in high school instead of learn how be i do so far',
#  'well to answer the should be any player who nadal play who appear in the top at some point',
#  'how funny how funny',
#  'please do not carry on conversation with other on my talk that be why you all have talk',
#  'i almost a year after the fact but the fact be most bank do that happen to me when i at another bank',
#  'second verse same a the first http secure wikimedia org index php title special renameuser reason usurp oldusername flynx newusername flynx_ usurp suppressredirect i you can see but not check xenotalk',
#  'or swansea bay article',
#  'definition soap box tabalso soap box an improvise platform a one on a street from which a speaker deliver an informal speech an appeal or political harangue rangue      show spell pronunciation huh ring show ipa noun verb rangued rangu ing noun taba scold or a long or intense verbal attack diatribe taba long passionate and vehement speech esp one deliver before a public gather tabany long pompous speech or of a tediously hortatory or didactic nature sermonize lecture or discourse kangaroo court   noun taba self appoint or mob operate tribunal that disregard or parody exist principle of law or human right esp one in a frontier area or among criminal in prison tabany crudely or irregularly operate court esp one so control a to render a fair trial impossible',
#  'be i go mad i on steven segal this morning and i sure say on the aug steven segal have a heart attack on the film set do i read this or be i go mad aug',
#  'then i you may be miss something the box art be replete with jpg dither all along the leave side and in random other spot the version be near crystal clear with no evidence of pixelation or dither or smudge a be present in the version a i say in my edit note i have no problem with the version be at such a when a high quality version be the revert war a be start by the other who for no legitimate reason revert my edit',
#  'advice to save me too much a lot of this be go to be link to exist policy and guideline there be plenty of advice available in fact a confuse amount so pointer may be helpful the guide to your first article and the business faq be particularly useful frown on about your own organisation because of worry that someone with a conflict of interest will not be able to from the neutral point of view which be one of our three key content policy the others be verifiability and no original research however the anonymity of account name mean can be prohibit and may be to have a declare interest than somone push a case anonymously should be possible for you to an article about your organisation that win get delete if you be careful the first essential be to avoid any hint of promotion be drily factual a though you be unconnected with the organisation and have no interest in but be document for completeness see the guideline on peacock term the next point be likely to be the problem if your organisation be notability which be the term for of enough general interest for an encyclopedia article see the guideline on notability and notability organisation and company what you have to do be from reliable source which be independent of you your own web site etc be not consider independent there be comment on your organisation in the trade press may be that you will have to wait until you be more establish and can cite independent i the above off line now that i come to post i see you have run into another problem copyright that more of a problem than you might because everything in must release under the gfdl which say that anyone may do anything with include rework for commercial so just say i agree to this be put in be not enough the notice above tell you what you can do but for the reason in my third para above be very likely that your mission statement will not be in suitable term for so the solution to the copyright problem may well be to rewrite that lead me to a last warn an important difference between and a business directory be that you will not own your article see own other people can and will edit see the warn at the bottom of the you to edit if you don your to be edit mercilessly or redistribute for profit by others do not submit regard',
#  'i he greek',
#  'please do not vandalize a you do with this edit to religious persecution if you continue to do so you will be block from edit',
#  'note and continue to vandalize this by include non source information pertain to a boyfriend name chad eagleton txmaster upload a picture on in which he state that he be chad eagleton these claim be most likely dubious attempt by the two who be probably actually the same person to claim that they be date carrie underwood a none of their claim be source i along with several other continue to delete them neither step up to the challenge of provide a source for their claim please continue to delete their constant vandalism',
#  'far more honest than this bloat article no disagreement censor stick',
#  'i believe the rule include non bind electron a well a bond electron too anyone to verify this and change',
#  'runnymede bob you remove a link from a that i create and develop be that appropriate',
#  'sorry you be right i have confuse matter iwill to clean up',
#  'recent past please see',
#  'your gay douche gay porno ahaghagagagaa',
#  'well i a article could fall out of but i just a little unsure where to start i a couple of book to mine though so there definitely potential you right that the should be convert to prose the demolition plan and their opposition also need expansion i tinker with a bite late today if i get a talk cont',
#  'the precede unsigned comment by talk contri bullshit april utc',
#  'you you for your constructive contribution to my update on the jodeci article jojo however this commet most uncalled for copyedit treason addition',
#  'block because of their paedo article if you go to http org wiki virgin_killer you will see people and protect a photo that show a real underage girl about in bondage however block me and not the people who be protect that photo i guess that be how be',
#  'i see that we be with different definition of nationality here but if and i you for bring up this example hold american citizenship not make a person american what else be henry kissinger bear in germany to german parent naturalise citizen a german politician then very tricky i must say anyways nice talk to you',
#  'do not help the jew schnider final warn',
#  'you be very welcome mila by the you or we could perhaps also place a copy of that image on the polyceridae a fmaily of nudibranch because that specie triopha catalinae cooper sea clown triopha be there since belong to that family since the specie name triopha catalinae be link to a non existent we could even if we felt to start a for that specie by the in english the word nudibranch be spell without the i do to up your image on bill site but i not able to get to the exact on a lot of them just a and at the present i do not take the to to track down any far maybe i will do that late',
#  'if the title never actually create i wouldn have be in the the prior announcement might be but that be generally just to be baron follow by a of name sound discuss and choose but he die before actually gazette so seem likely there only be an informal record of what go to be talk',
#  'extremely salient point somethings i have not consider the undeerlying intention a to dissuade edit noo bullshit from run by makiing everything sound so complicate while at the same offer some encouragement for those who have some clue but be afraid to come forward but you probably right about the nom statement i have another at a recent rfa tank suddenly follow a revelation by ireonholds if candidate have skellies in their closet the should do something about before they run i have some in mine but they be all over a year old didn stop them from though lot of silly nonsense this morning my about get you indef instead of ironic really see a you have defend his strange behaviour several in the past well to bang my head at the wall again i really here to let you that special finally reach the day mark today be interest to how many be in that backlog i don how to them all',
#  'i take you do read this great block ryan andemu',
#  'i admit what i do improper and wont happen again',
#  'tag for possible deletion on derry city relate photo i notice you have place a tag for possible deletion on numerous photograph of player at the club these be personal photo some i have crop maybe i tag them incorrectly could you guide me a to how to tag them or ensure that they stay on the site',
#  'killer whale attack on human this revert see here talk early boracay bill',
#  'nico contain a lot of in universe or that revolve around the fictitious world of the character see the link in the tag on the for more detail also if you can any reliable on google feel free to them these two be the least fun to do and i help talk',
#  'still big can you change with your admin power i don mere wpedians can do this kind of if i do cut and paste mak get upset',
#  'i self explanatory i guess not be not a spoof be a freelance article filler for the issue but not take seriously and the not create by a note music critic or someone of note in the music industry in japan this would be someone masanori ito and the magazine even make sure to mention be bias and arbitrary they even make note of that on the cover and again my point be how be this acceptable for the i can even believe i need to ask that should top of the great rock song of all etc be in the relevant wiki article a an award or achievement a well that be neither an award or achievement apart from that provide no information to the article be fancruft nonsense my question how be acceptable for the and especially give the fact be bias and randomly put together',
#  'no album root be mantly groove metal but song root bloody root be death metal song see google number do not lie',
#  'this article include a link to the center for marcionite research we bullshit ite that we bullshit ite be part of geocities and will go offline tomorrow so i have make the link point to a mirror of the we bullshit ite instead',
#  'and you be a motherfucking asshole suck your dick you dirty son of a whore',
#  'be you sure your greek be not let say native',
#  'i have to say i disagree a little bite on the colorado and michigan state game appalachian state definitely deserve mention but colorado and michigan state while both have great and interest finish be not important enough to be mention in the header particularly when you combine with the a bullshit ence of the army game and the and ohio state michigan game the game in particular because woody admit that his best team and the wolverine cost the buckeye what would have surely be a national title since the buckeye be lock out of the rise bowl if colorado and michigan state be worth mention then so be illinois and notre dame interest great game but probably not worthy of be put in the header speak of which those game should be incorporate into the history that may be do by the you read this',
#  'mar utc this be the discussion for an anonymous who not create an account yet or who not we therefore have to the numerical address to identify him her such an address can be share by several if you be an anonymous and feel that irrelevant comment have be direct at you please create an account or log in to avoid future confusion with other anonymous',
#  'speedy deletion of frugooscape a you create frugooscape be tag for deletion in accordance with our deletion policy in particular meet one or more criterion for speedy deletion the relevant criterion be patent nonsense and gibberish an unsalvageably incoherent with no meaningful content you be welcome to contribute content which comply with our content policy and any applicable inclusion guideline however please do not simply create the with the same content you may also wish to read our introduction to edit and guide to your first article if you have any question please contact an administrator for assistance you talk',
#  'why would a on this we bullshit ite call talk ranger be the bearer of truth on the liquidation of the club because the term old firm never official who the final say on existence because if unofficial then surely anyone who us be do so in an opinionated expression in all honesty you couldn produce anything that declare the term old firm a an official description much the same a what the firm be for dundee utd and aberdeen similarly what nimmo smith delacred the ranger in common speech can be deem a continue entity he have to that in common speech term because lord nimmo smith that in law ranger form in be officially liquidate there your difference that what the old firm term be in common speech but not strictly official',
#  'don talk to me troll',
#  'my above heartfelt apology extend to you here rich farmbrough imacowboy',
#  'commodore ballroom the sentence grammy and juno award win band while many of those band have in fact play at the venue they be not in that category talk',
#  'apple and orange jonathan raban be not a rabid extremist he not make his live by iconoclasm provocation and controversialism he just a serious english author who life part in america and whose view be take seriously across all political spectrum except yours and killerchihuahua apparently',
#  'criticism i a criticism should be many important thinker have state the negative effect broadcast of sport cause to modern society',
#  'should we even mention this however block video can still be view by change the url if youtube a legal basis for block video by country seem we shouldn mention how to bypass no matter how totally obvious be talk',
#  'intelligent and honest reader',
#  'if you really to shorten thus probably the first step would be to copy all to the sub article so that none of the material be lose',
#  'please do not defamatory content to a you do to of wwe intercontinental champion what a fuck hypocrite the fact that you leave me a message tell me what a fuck douchebag i be just go to show what a massive tool you be just for your information that day rule something i start year ago',
#  'willie wang a tag be place on willie wang request that be speedily delete from this be do because the article seem to be about a person group of people band club company or web content but not indicate how or why the subject be notable that be why an article about that subject should be include in under the criterion for speedy deletion article that do not assert notability may be delete at any please see the guideline for what be generally accept a notable and if you can indicate why the subject of this article be notable you may contest the tag to do this please on the top of the and leave a note on the article talk explain your position please do not remove the speedy deletion tag yourself but don hesitate to information to the article that would confirm subject notability under the guideline for guideline on specific type of article you may to check out out our criterion for biography for web site for band or for company feel free to leave a note on my talk if you have any question about this paul zheng a tag be place on paul zheng request that be speedily delete from this be do because the article seem to be about a person group of people band club company or web content but not indicate how or why the subject be notable that be why an article about that subject should be include in under the criterion for speedy deletion article that do not assert notability may be delete at any please see the guideline for what be generally accept a notable and if you can indicate why the subject of this article be notable you may contest the tag to do this please on the top of the and leave a note on the article talk explain your position please do not remove the speedy deletion tag yourself but don hesitate to information to the article that would confirm subject notability under the guideline for guideline on specific type of article you may to check out out our criterion for biography for web site for band or for company feel free to leave a note on my talk if you have any question about this michael cho a tag be place on michael cho request that be speedily delete from this be do because the article seem to be about a person group of people band club company or web content but not indicate how or why the subject be notable that be why an article about that subject should be include in under the criterion for speedy deletion article that do not assert notability may be delete at any please see the guideline for what be generally accept a notable and if you can indicate why the subject of this article be notable you may contest the tag to do this please on the top of the and leave a note on the article talk explain your position please do not remove the speedy deletion tag yourself but don hesitate to information to the article that would confirm subject notability under the guideline for guideline on specific type of article you may to check out out our criterion for biography for web site for band or for company feel free to leave a note on my talk if you have any question about this this be a serious encyclopedia be not myspace please do not create article on yourself or your firends',
#  'a kitten for you lolz',
#  'copyright problem remove this article base on powell a zealand mollusca william collins publisher ltd auckland zealand isbn be revise on this date to eliminate a probable copyright violation of that book early text must not be restore unless can be verify to be free of infringement for legal reason we cannot accept copyright text or image borrow from other web site or print material such addition will be delete contributor may external we bullshit ites a a source of information but not a a source of sentence or phrase accordingly the material may be rewrite but only if not infringe on the copyright of the original or plagiarize from that source please see our guideline on non free text for how to properly implement limit quotation of copyright text take copyright violation very seriously and persistent violator will be block from edit while we appreciate contribution we must require all contributor to understand and comply with these policy for background on this situation please see the relate administrator noticeboard discussion you talk',
#  'well i learn the hard with a three month topic ban on ayn rand article deal with the american equivalent of irvine and by whose standard irvine be mild the call a spade a spade issue unfortunate either his her late escapade earn a week block the next will be long however i see that rockpocket be set him her up with target talk',
#  'be not an indiscriminate collection of information unless and until you can show with reliable source that this information be notableas in widely cover in mainstream sourcesit simply not belong',
#  'then how be i suppose to communicate',
#  'through this article why do you that entry be make or mean to irritate other that wasn the intention however',
#  'no i not rant and you tautology about if they edit against the sanction they will be sanction be both laughable and irrelevant i interest in editorial behavior and effect and the odds be vanishingly slim you be even a remotely qualify a i be to have an opinion in these kind of matter keep mash button and your eye off the big picture',
#  'no but i can really be bother to argue about any more tag counsellor of state',
#  'oak and homophobia i provide a full citation that prof oak homophobia how the fuck be that vandalism',
#  'be a scientifically prove epitome of an arsehole stretch and itch that why he whine and bitch so pathetically on wikipaedia female masturbation technique be quite numerous and perhaps more vary than those of male they be influence by a number of factor and personal preference technique include stroke or rub of the vulva especially the clitoris with the middle index and or second finger sometimes one or more finger may be insert into the vagina to repeatedly stroke the frontal wall of the vagina where the spot be locate study do by master johnson however have show that only about of woman actually have orgasm through vaginal stimulation alone citation need masturbation aid such a a vibrator dildo or ben ball can also be to stimulate the vagina and clitoris many woman will caress the breast or stimulate a nipple with the free hand anal stimulation be also enjoy by some because of the thousand of sensitive nerve end locate there lubrication be sometimes during masturbation especially when penetration be involve but this be by no mean universal and many woman their natural lubrication sufficient some even produce more lubricant alone than with a partner though the reason for this seem to be primarily psychological woman may masturbate in the bathtub shower and hot tub sometimes include the of warm run water to stimulate the clitoris common position include lie on back or face down sit squat or even stand lie face down one may straddle a pillow the corner or edge of the bed a partner leg or some scrunch up clothe and hump the vulva and clitoris against stand up the corner of an item of furniture or even a wash machine can be to stimulate the clitoris through the labium and clothe a vibrate duck by dramatise the nature of a vibrator this kind of toy gain wide acceptance some reach orgasm merely by cross their leg tightly and clench the muscle in their leg which create pressure on the genitals this can potentially be do in public without bullshit ervers notice some prefer to only pressure apply to the clitoris without direct contact for example by press the palm or ball of the hand against underwear or other clothe a few woman can orgasm spontaneously after experience prior sexual arousal due to intellectual stimulation alone for instance listen to certain piece of music often these mental trigger have association with previous instance of arousal and orgasm some woman claim to be able to orgasm spontaneously by force of will alone but that ability if exist at all may not strictly qualify a masturbation a no physical stimulus be involve those who have difficulty reach orgasm through sexual intercourse may easy to achieve an orgasm through masturbation sometimes sex therapist will recommend that female patient take to masturbate to orgasm especially if they have not masturbate before',
#  'adam jwc hi sardaka the above be sockpuppet account and be still allow to have his account can you pls show me how to report him a he be still abuse this we bullshit ite',
#  'to zora i have get all the picture from one webpage and i dod not see any copyright rule but just to be safe i will take them down and late i will one with copyright',
#  'pax stop pro serb source so much make you a serb nationalist and i that you aren and that you to act neutral other source besides serb source a ser bullshit tend to propogand with their especially in history just remember that',
#  'my pleasue you deserve and you for consider the review mean a lot to me cheer talk',
#  'you get another come picker always win picker',
#  'all this be cite make your complaint feeble and unjustified for someone who claim to be a luftwaffe unthusiast for you to calim caldwell dubious a a source be the best one i have hear from you caldwell make a point of report loss by the side that suffer them he always mention overclaiming specfific date be give a you well either that or you don read properly no doesn syas raf mustang be include a well the context be you have be place information into the day to which say the bulk of the operate there caldwell and muller say this be a non no they be more reliable than shore who focsus more on ally air force do an online search on caldwell',
#  'parkwells yes i go to the source you refer link to regard other visitor to monticello and they have this to say these family member be not mention in thomas jefferson farm book a be visitor to monticello the farm book not appear to be a log of visitor but an account of his plantation livestock land crop cost and slave not a logbook of visitor hardly compel schulz your notion that hyland book be ignore by scholar simply because be not mention at the cite you link to be ridiculous esp since indeed be endorse by many scholar include former member of the tjf hyland be adjunct professor at stetson university college of law at tampa bay florida if you that hyland be dead why don you send him an email whyland traveler com and see how he feel about that you have the wrong hyland hyland book come out in the hyland you refer to die in please do you homework and if you be ready to dismiss a source because of two spell error be clear that your mind be quite close and simply can come to term with the idea that there be a whole body of historian professor who exist outside of the box you seem to have enclose yourself in even albert einstein a poor speller btw in the same paragraph you make issue with spell error you make a grammatical error leave a word out of your sentence that say hyland book be not a particularly book be this your of say you not reliable unbelievable both of you be clutch at straw and be not be fair to other point of view',
# ...
#  'you get i start do that from now on',
#  'no ive never be lucky enough to go to one of his concert might be a case of carry on on flickr until we one thats and doesnt a press attachment not really familiar with copy right rule their quite complicate a possibility would be a music video still or a concert that in the public domain such a his superbowl performance in come speak to me',
#  'black text on a plain background elicit reliably fast read performance than on a medium textured background when compare to read light text on a dark background people read black text on a white background up to thirty two percent fast in general the great the contrast between the text and background the easy the text be to read research base web design usability guideline chapter http usability gov pdfs chapter pdf',
#  'frankly i dont have the nor the inclination to sit and argue with you if you do well why dont you just go and screw urself',
#  'this be not the bowl for comumbine article and i have see that movie i own a copy and i still can figure out what mmoore be say and i a card carry nra member and a huge fan on the ammendment funny when we cite the science community who correctly say ben blame the nazi on darwin everyone go nut and say we shouldn scientist a a source when we include the perspective of professioanl film reviewer who coincidentally have come to the exact same conclusion that the science dude do we encourage to ignore them a well and instead rely on a pov when this pov push stop',
#  'we be over this a thousand and your comment be not a constructive one not every picture of a sexual act be pornography',
#  'uncyclopedia so now you aren proud of this anymore http org index php title sir_james_paul diff prev oldid',
#  'our talk archive',
#  'if my name to go every muslim with allah in his name to pick a one too',
#  'hi katana for the burke group if you just revert to the previous version that i last edit you see magically no long be an advertisement because a few anonymous people keep turn into one and excise term union buster and any neutral info about what they actually do so please go ahead and revert',
#  'hcr box grassy',
#  'wow a snide rude response from xeworlebi there a shocker clearly you be mark the disambiguation incorrectly but you be too arrogant to listen',
#  'no one be than chad bryant',
#  'maybe you have the wrong around',
#  'ludwig von salm hoogstraeten i do with i promise nominate for dyk holla me',
#  'redirect talk pakan electoral district',
#  'that be redundant a a duplicate entry to the meatpuppetry case already be discuss at ani that unfortunately result in wikihounding off this we bullshit ite',
#  'irving literary society cornell university deletionism and inclusionism in neutral point of view third party review wikiproject york post transfer from hi cmagha i never saw the original afd discussion but i the article the start of something fantastic my only concern would be that the majority of your seem to come from cornell specific source i cornell daily sun cornell era cornell register etc college university publish source be a bite of a grey area within when deal with a campus organization a some may not consider these to be independent of the subject that be say we aren deal with a fly by night college band that play at moonshadows and have a writeup in the ithacan this be a literary society almost a old a cornell university itself and have significance well beyond east hill despite the large number of orient source which i personally believe be independent you have enough that would be unambiguously independent to survive another afd if need be i post what you have now and keep for more say you say two wow great sorry i be out of the loop double smiley face from the syracuse orangeman bring in to ensure neutrality the critic need to read the article from a distance this be hardly promotional when you about be basically say that cornell university have a chance to excell in an intellectual activity and tank we obviously would not have do that at i do there be a sumner cite out there to that cmagha miss will for wiptransferred from pageoversaw your preparation at since others may communicate here now and again you may to move your editorial note to a subpage talk for the tip very hard to learn lot of the intricacy of the wikiworld i stll have some prep to do before ask the administrator to move that article over there be two in particular who be still a little raw on the article and the administrator while fair and neutral be tough guidance from administtrator october just review the irving article again notability address in the first seven footnote will move back into the mainspace unless you have additional concern i ready to go also see on cmagha that others have review positively what be the remain objection and how do we appeal if there be still objection here be the spartaz if you need a refresher http org wiki cmagha the_irving_literary_society_ cornell_university take to drv please humbug administrator guidance to july copy from spartaz the irving article be notice on the wikiproject york some helpful comment send back do not receive notice on your decision we will be ask to move the article back to mainspace shortly for the aid no unless you have address the significant issue concern allegation of misrepresent source and the contention that all of the source be tangential or trivial then this isn go back into mainspace humbug material for spartaz to review prior to decide whether to move article to mainspace july comparators in order of to more evidence sphinx senior society notability base incredibly on primary',
#  'i just a bullet point to the significant event',
#  'cinq do you how quebeckers pronounce the word cinq',
#  'block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block block',
#  'fuck you andre michael brown you undersized cowardly pussy you and that pussy as dipshit bitch grey jinjo be sorely in need of an as kick',
#  'project feel free to edit my talk a need i just to get start treat a your own entry',
#  'arrogance how pretentious of you to make a for yourself',
#  'i wholeheartedly disagree with your stance on the subject i believe there be ample evidence to prove the company under the supervision of the ceo in question not only constructive but accurate terry semel run a company which give money to lobby group which wish to alter the design of the internet to favor profit over ingenuity this would effectively change the measure for which code be rank since would also be determine by purchase bandwidth priority over performance this would not only have an effect on those involve in the program industry but change the the internet for the entire world now from own article on the subject an asshole be slang describe a the word be mainly a a profanity towards someone the speaker not or whose behavior be hurtful self center or particularly abrasive now sell out the free world wide accessible library and program performance for profit be particularly self center and hurtful behavior which influence the world since this do during his career this be where i summarize quite eloquently word from the culture he himself propagate',
#  'and his otter break clamshell otter chirp help',
#  'please stop if you continue to vandalise a you do to khyber pas you will be block if this be an share address ignore this notice if wasn you who make the edit',
#  'very nice i be be harass my edit disrupt and now i get block for harassment i be out of here you bully',
#  'read your nomination i your answer to answer about the aiv question so you do handle well',
#  'harry technique shouldn we mention the harry technique the one where you hold the pistol with the right hand and the leave arm be under the right at a perpendicular angle hold a flashlight forward',
#  'plot much too long detail and subjective read motivation and mean into the movie where none be explicit i condense the movie into a brief synopsis i don believe a scene by scene relate of the entire movie be necessary or appropriate this seem to be a real problem with movie over detail plot which often the pov and bias i a short synopsis be much likely to suffer from this problem',
#  'berceuse you welcome a pleasure to see something so immediately expandable while scroll through recent change happy edit oct utc',
#  'how can you have a place without picture i place a picture link someone remove why',
#  'speak career i there should be a about his speak career and the quote he make during this',
#  'also to be quite honest i your action objectionable first you innapropriately revert comment i make to some talk in response to some bad advertise on the part of racepacket then you block me because i suggest that the mentor group review whether racepacket shoudl be a mentor be else shoudl i take a question that if i or any feel that an be not fit to be a mentor then we should say something without beign worry about be block this be ridiculous',
#  'my plan fail i don so',
#  'in this case i remove to phil talk per our policy for off topic stuff that turn up on an tony sidaway',
#  'gummo marx be relatively unknown and have the lousy luck of quit before the act become famous xenia be likewise little and unlucky at least that my guess i could be talk out of my as',
#  'minnesota portal nomination the portal you nominate at feature portal candidate on february be promote to feature portal status well do you can view eventual comment at the nomination however please be aware that there this thread could be view a canvass for support which could affect the overall result of whether the portal should be promote or not regard',
#  'i be sorry i this stupid sentence at about clock in the night the definition be perfectly correct and even well',
#  'warn greet you have revert the online creation article in than hour i will instead take this opportunity to point you in the direction of own and consensus and respectfully ask that you reflect upon how that policy may be relevant to your feel toward the online creation article please refrain from far revert and please attempt to meet your fellow in some sort of compromise on the appropriate talk',
#  'shouldnt someone that kung fuckis useless against modern mma martial artist and that be a die sport which become useless against muay thai bjj judo pankration and sambo',
#  'a per my response to your response on your talk to my comment you haven answer my question where the evidence i be continue to engage in battleground behaviour blp apply to any content about live person not just to biography right so which be why doesn apply to counterpunch because a magazine so what if my edit unbalance the article if you feel that unbalance then quote of praise for the magazine there nothing wrong with put blp content out of article in the a bullshit ence of consensus although in this case what we deal with isn a blp issue i also say just a much a there consensus for the inclusion of my content there be no consensus of exclusion of my content either no i be not go to apologize for call you something true which be why i be post this on my talkpage if you to respond although i should let you doesn matter whether you do or not fellytone talk',
#  'plus or minus if a player be on the ice and his team get score against he get a if he be on the ice and his team score he get a the league average be around and the leader be around   talk',
#  'put up or shut up to all you people who the president be do such a terrible job why don you run for president and when you get elect and do really easy to play the monday morning quarterback one to disagree with his foriegn policy another to criticise him for decision he make when you don what information he have at the we may not have the best system but at least we have a man who be not afraid of make the tough call',
#  'the gather from the vault dragon',
#  'angell center picture that picture be pretty interest i a current student and this be a picture of the reverse angle take from the walkway between yokum and feinberg i i might upload a creative common and to the state university of york at plattsburgh',
#  'muhammad teacher i this be quite difficult to accept for you muslim but a be this guy one of several muhammad teacher this be an irrefutable fact of history i realise that the idea of muhammad have a teacher beside allah be some kind of heresy for you but here the truth muhammad have an assyrian christian teacher muhammad learn a lot from him i be not misrepresent any source by point out this well fact amongst theologian may be so that sargis bkheera do not teach muhammad about everything but muhammad glean a lot from him here what aina say a muhammad declare himself the prophet of god and originate islam be well that muhammad principal teacher the assyrian monk sargis bkheera this account for the extraordinary doctrinal similarity between some aspect of islam and the assyrian church of the east for example accord to assyrian church doctrine there be no awareness of passage of between the moment of death and final judgement final judgement occur immediately even though thousand of year may have pass on earth islam hold this same view be also noteworthy that the koran state that in the day of final judgement the angel of allah will speak to man in assyrian http aina org aol peter timeline htm where do you muhammad get that from of course he get from his assyrian christian teacher you this from some academic i sure that no problem here you go take your pick he muhammad teacher stop revert unless you have some source refute this claim talk jun utc',
#  'then help me make more nuetral',
#  'and get to with people of different view rather than against them we all have to learn this at present the science doesn seem under real threat if get threaten there will be a storm for sure a gently understate at present and the issue and phrase in that have go through a long and torture so any change there be sure to reopen wind i take a close when i get back',
#  'utc not that any of the rest of have ever go past have a one vivaldi june',
#  'yay let all do the pedantic semantics dance roll eye i the only realistic approach be for larry sanger to discus this directly with jimbo our little pontifications on the issue win get solve or determine the proper party approve pov talk',
#  'no be not how be i suppose to',
#  'if you guy really discus napoleon you need to get a fuckin life be so sad that you would rather discus someone who be dead for year then to at porn you guy homosexualuals anal sex type',
#  'please consider this a a personal attack against the node dear node i do take personal pride and honor to say to you and your commander an well deserve fuck you and yes i a this moment your real identity please forgive me i to assure you and your family and this extend to the family of bortnikov that no harm intend or untended from me will occur a long process and some well spend money involve but i realize finally that you deserve only my mercy to you and yes this be my last post a i do realize that i have no place here i do much much in the real scientific world',
#  ...]
